# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200. # med res (400 = High res)

# %%
rg = default_rng(12345)
X = rg.uniform(low=0.0, high=10.0, size=(1000,))
X[:10]
# Out:
# array([2.27336022, 3.1675834 , 7.97365457, 6.76254671, 3.91109551,
#        3.32813928, 5.98308754, 1.86734186, 6.72756044, 9.41802865])

# %%
slope = 0.25
intercept = -1.25
y = slope * X + intercept + rg.normal(loc=0.0, scale=1.0, size=(1000,))

# %%
data = {"COL_A": [123, 234], 'COL_B': ['a', 'b']}
df = pd.DataFrame(data)

# %%
df
# Out:
#    COL_A COL_B
# 0    123     a
# 1    234     b

# %%
# Get one hot encoding of columns B
one_hot = pd.get_dummies(df['COL_B'])
# Drop column B as it is now encoded
df = df.drop('COL_B',axis = 1)
# Join the encoded df
df = df.join(one_hot)

# %%
df
# Out:
#    COL_A  a  b
# 0    123  1  0
# 1    234  0  1

# %%
plt.scatter(X,y,s=1)
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
lin_reg
# Out:
# LinearRegression()

# %%
lin_reg.fit(X.reshape(-1,1), y)
print(lin_reg.intercept_)
print(lin_reg.coef_)
# Out:
# -1.2522197212675916
# [0.25711689]

# %%
  y_pred = lin_reg.predict(X.reshape(-1,1))

# %%
plt.scatter(X,y,s=1)
plt.plot(X,y_pred,'r')
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
